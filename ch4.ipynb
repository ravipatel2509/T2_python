# %% [markdown]
# Machine Learning

# %% [markdown]
# Supervised:
#    past data:-I/P and O/P
# Unsupervised:
#     depend on cetogary

# %%
#Linear Regression:(I/P and O/P both are depend of each other)(stright line)
(ch-4)
-->
simple linear Regression :-only one peramter impect on o/p((o/p) ek jaa parmeter depend kare)
Multiple linear Regression((o/p) multiple parmeter depend kare)
Polynomiar Regression
(ch-5)
-->
KNN
Decision Tree

--->simple linear Regression :-only one peramter impect on o/p
y=mx+c
y=predict the value(depended)
x=partmeter help to predict value(indepedent)
m=slop of co-efficent


--->Multiple linear Regression((o/p) multiple parmeter depend kare)
y=m1x1+m2x2+m3x3+m4x4+m4x5+c

# %%
import pandas as pd
df=pd.read_csv("Book1.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
#verify this data is linear or not??
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(df["cgpa"],df["package"])
plt.xlabel("CGPA")
plt.ylabel("Package")
plt.show()

# %%
y=df["package"]#predict karvani value
x=df[["cgpa"]]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape)#2 dimnesion
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (160, 1)
# (40, 1)
# (160,)
# (40,)

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)#modal bani gayu
# Out:
# LinearRegression()

# %%
m=lr.coef_#(y=mx+c)return the value of m
m
# Out:
# array([0.57425647])

# %%
c=lr.intercept_# return the value of c
c
# Out:
# np.float64(-1.02700693745421)

# %%
y=(m*5.65)+c#prdict the value 
y
# Out:
# array([2.21754213])

# %%
y2=lr.predict([[5.65]])#in exam use this method
y2
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.21754213])

# %%
y_pred=lr.predict(x_test)#predict kari ne aapiyo answer package 
y_pred
# Out:
# array([2.78031348, 3.13635249, 3.1995207 , 2.38981908, 3.52684689,
#        3.76803461, 3.16506531, 2.54486832, 3.17655044, 3.4923915 ,
#        1.90744364, 2.34962112, 3.6876387 , 2.75734322, 3.47516381,
#        3.04447145, 2.32665086, 3.20526327, 2.17734418, 3.314372  ,
#        2.45298729, 2.90090734, 3.32011456, 2.87219451, 3.33734226,
#        2.19457187, 1.41932564, 2.7114027 , 3.18229301, 2.32665086,
#        3.74506435, 2.95833298, 3.68189614, 2.97556068, 2.59080884,
#        3.34882738, 2.47595755, 3.07318428, 4.17575671, 2.95833298])

# %%
# #testing
# --->MSE(mean square error)

from sklearn.metrics import mean_squared_error
print("MSE=",mean_squared_error(y_test,y_pred))
# Out:
# MSE= 0.08417638361329657

# %%
import pandas as pd
df=pd.read_csv("student_scores.csv")
df.head(5)
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
y=df["Scores"]
x=df[["Hours"]]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape)#2 dimnesion
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (20, 1)
# (5, 1)
# (20,)
# (5,)

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()
lr
# Out:
# LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
m=lr.coef_ 
m
# Out:
# array([9.68207815])

# %%
c=lr.intercept_# return the value of c
c
# Out:
# np.float64(2.826892353899737)

# %%
y_pred=lr.predict(x_test)#predict kari ne aapiyo answer package 
y_pred

from sklearn.metrics import mean_squared_error
print("MSE=",mean_squared_error(y_test,y_pred))
# Out:
# MSE= 18.943211722315272
